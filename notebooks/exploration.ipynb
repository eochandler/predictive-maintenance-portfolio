# %% [markdown]
# # Exploration
# Messy EDA lives here. Once you know what your pipeline needs, move clean logic into `src/`.

# %%
import sys
sys.path.append('..')

from src.data_loader import load_raw_data, add_rul_labels

df = load_raw_data('../data/raw/train_FD001.txt')
df = add_rul_labels(df)
df.head()
